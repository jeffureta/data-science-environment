# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# **Objectives**
# - List popular languages used in data science
# - List popular libraries used in data science
# - Covered how to to basic arithmetic in Jupter Notebook
# ## Author
# Jeff Ureta

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are Summarized

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. Julia
# 6. Scala

# %% [markdown]
# Some of the popular languages that Data Scientist use are:
#
# 1. Data processing and modelling
#     - SciPy
#     - NumPy
#     - Pandas
#     - Scikit-Learn
# 2. Data Visualization
#     - Matplotlib
#     - Seaborn
#     - Plotly

# %% [markdown]
# Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# |Data Science Tools|
# ------------------------
# |Anaconda                |
# |JupyterLab Notebook & Jupyter Notebook  |
# |Visual Studio Code|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
minutes = 200
hours = 60
print(f"200minutes converted to hours is {minutes/hours}")
# Out:
# 200minutes converted to hours is 3.3333333333333335
